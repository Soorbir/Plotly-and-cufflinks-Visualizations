# %% [markdown]
# #  Plotly and Cufflinks

# %% [markdown]
# Plotly is a library that allows you to create interactive plots that you can use in dashboards or websites (you can save them as html files or static images).
#
# ## Installation
#
# In order for this all to work, you'll need to install plotly and cufflinks to call plots directly off of a pandas dataframe. These libraries are not currently available through **conda** but are available through **pip**. Install the libraries at your command line/terminal using:
#
#     pip install plotly
#     pip install cufflinks

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

import plotly.graph_objs as go
from  plotly.offline import plot

import chart_studio.plotly as py
import cufflinks as cf
cf.go_offline()

from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot
init_notebook_mode(connected='true')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
#Creating a Box Plot

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df.head()
df.iplot(kind='box')
# Out:
# <div>                            <div id="725e7f00-cc1e-4b22-91d1-95396d92cf91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#Importing data from excel

# %%
datau=(pd.read_excel(r'C:\Users\gurvi\Downloads\upsdata.xlsx'))
datau
# Out:
#     Year  Revenue in mil USD  Net income in mil. USD  Total Assets in mil. USD
# 0   2005               42581                    3870                     34947
# 1   2006               47547                    4202                     33210
# 2   2007               49692                     382                     39042
# 3   2008               51486                    3003                     31879
# 4   2009               45297                    1968                     31883
# 5   2010               49545                    3338                     33597
# 6   2011               53105                    3804                     34701
# 7   2012               54127                     807                     38863
# 8   2013               55438                    4372                     36212
# 9   2014               58232                    3032                     35440
# 10  2015               58363                    4844                     38311
# ...

# %%
#Creating a simple iplot that visualize the revenue with respect to year on x axis with three categorization on the graph

# %%
datau.iplot(x="Year")
# Out:
# <div>                            <div id="acf8ddcc-a627-4f77-95ba-b53fa7260c91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df=pd.DataFrame(np.random.randn(100,4),columns=["A","B","C","D"])
df2=pd.DataFrame({"Category":["A","B","C","D"],"Values":[20,34,12,42]})
df2
# Out:
#   Category  Values
# 0        A      20
# 1        B      34
# 2        C      12
# 3        D      42

# %%
df
# Out:
#            A         B         C         D
# 0   0.099710 -0.263823  1.574109 -0.595707
# 1  -0.217394 -0.206206 -0.911469 -0.477257
# 2   0.159963 -0.736040 -0.305156  0.037800
# 3  -0.347384 -0.787363 -0.241803 -0.954345
# 4  -2.254416 -1.127392 -1.541188 -0.587858
# ..       ...       ...       ...       ...
# 95  0.289961  0.273525  0.238733 -0.604879
# 96 -0.003439  0.466458 -0.240507 -0.323519
# 97 -0.846006 -0.411927  1.157089 -0.059928
# 98  0.964868 -1.021549  0.613454  0.830997
# 99  0.015009 -0.759209  0.759018 -0.370220
#
# [100 rows x 4 columns]

# %%
# Creating a scatter Plot

# %%
df.iplot(kind="scatter",x="A",y="B",mode="markers",size=5)
# Out:
# <div>                            <div id="500887f7-e5dd-4f18-96e3-c55d28ebe821" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Creating a bar plot

# %%
df2.iplot(kind="bar",x="Category",y="Values")
# Out:
# <div>                            <div id="d05d25f3-828c-4f0f-afe3-20d3b4c825d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind="bar")
# Out:
# <div>                            <div id="92b7e0a4-356b-4c5b-8cc7-cc6929e4da78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head(5).iplot(kind="bar")
# Out:
# <div>                            <div id="6d0f37a3-4a0e-4569-b3ef-078e07f1c0b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.sum().iplot(kind="bar")
# Out:
# <div>                            <div id="8a19e543-006d-4cac-be53-b27d8ae49f74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#            A         B         C         D
# 0  -3.338570  0.509638  0.365558  0.486752
# 1  -0.940483  0.538881 -0.089924  0.281602
# 2  -0.732132 -1.004066 -0.307913 -0.922251
# 3  -0.853409  2.737410 -0.811634  0.503152
# 4  -0.347435  0.187719 -1.451179  1.378315
# ..       ...       ...       ...       ...
# 95  1.175759  0.239361  0.615912  0.698906
# 96 -1.203502  0.863361 -0.673497 -0.303624
# 97  0.291107  0.170560  0.104708 -0.150654
# 98 -1.600281 -0.297908  1.196268  0.110100
# 99 -1.350554  1.670513  0.760736 -0.883602
#
# [100 rows x 4 columns]

# %%
#Creating Box iplot

# %%
df.iplot(kind="box")
# Out:
# <div>                            <div id="f9a834b6-01a7-48d8-997f-b1586f3d6f0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3=pd.DataFrame({"x":[1,2,3,4,5],"y":[10,20,30,20,10],"z":[5,4,3,2,1]})

# %%
#Creating 3d surface iplot

# %%
df3.iplot(kind="surface",colorscale="rdylbu")
# Out:
# <div>                            <div id="7d13d8d3-4faa-4a73-b7fd-355ebea4e43d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Creating Hist iPlot

# %%
df.iplot(kind="hist")
# Out:
# <div>                            <div id="679bc402-4db1-4f3e-ab95-5b146fb1c5a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Creating Spread Plot

# %%
df[["A","B"]].iplot(kind="spread")
# Out:
# C:\Users\gurvi\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\gurvi\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>                            <div id="aaaed00a-9525-4672-b7a0-182c6e9b99ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Creating 3d Bubble iplot

# %%
df.head(20).iplot(kind="bubble3d",x="A",y="B",z="C",size="C",colorscale="plotly")
# Out:
# <div>                            <div id="9ca4fbfa-a189-42b8-a053-8eff2dbcfce9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.datagen.bubble3d(5,4,mode='stocks').iplot(kind='bubble3d',x='x',y='y',z='z',size='size',text='text',categories='categories',
                            title='Cufflinks - Bubble 3D Chart',colorscale='set1',
                            width=.5,opacity=.9)
# Out:
# <div>                            <div id="af0babef-8578-4a06-821a-0c6eddaa8898" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
